# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('oil_geopolitics_dataset_2010_2026.csv')
df
# Out:
#           date  brent_price  wti_price  dxy_index        vix   gpr_index  \
# 0     17-02-10    76.269997  77.330002  80.379997  21.719999   80.725357
# 1     18-02-10    77.779999  79.059998  80.400002  20.629999   80.725357
# 2     19-02-10    78.190002  79.809998  80.639999  20.020000   80.725357
# 3     22-02-10    78.610001  80.160004  80.510002  19.940001   80.725357
# 4     23-02-10    77.250000  78.860001  80.849998  21.370001   80.725357
# ...        ...          ...        ...        ...        ...         ...
# 4042  06-03-26    92.690002  90.900002  98.989998  29.490000  130.887665
# 4043  09-03-26    98.959999  94.769997  99.180000  25.500000  130.887665
# 4044  10-03-26    87.800003  83.449997  98.830002  24.930000  130.887665
# 4045  11-03-26    91.980003  87.250000  99.230003  24.230000  130.887665
# 4046  12-03-26    95.760002  94.309998  99.463997  24.230000  130.887665
#
#       brent_return  wti_return  brent_lag_1  brent_lag_3  ...  wti_lag_7  \
# ...

# %%
df.shape
# Out:
# (4047, 23)

# %%
df.head()
# Out:
#        date  brent_price  wti_price  dxy_index        vix  gpr_index  \
# 0  17-02-10    76.269997  77.330002  80.379997  21.719999  80.725357
# 1  18-02-10    77.779999  79.059998  80.400002  20.629999  80.725357
# 2  19-02-10    78.190002  79.809998  80.639999  20.020000  80.725357
# 3  22-02-10    78.610001  80.160004  80.510002  19.940001  80.725357
# 4  23-02-10    77.250000  78.860001  80.849998  21.370001  80.725357
#
#    brent_return  wti_return  brent_lag_1  brent_lag_3  ...  wti_lag_7  \
# 0      0.007796    0.004155    75.680000    73.050003  ...  71.190002
# 1      0.019798    0.022372    76.269997    72.900002  ...  71.889999
# 2      0.005271    0.009486    77.779999    75.680000  ...  73.750000
# 3      0.005372    0.004385    78.190002    76.269997  ...  74.519997
# 4     -0.017301   -0.016218    78.610001    77.779999  ...  75.279999
#
#    brent_volatility_7d  brent_volatility_30d  wti_volatility_7d  \
# ...

# %%
df.tail()
# Out:
#           date  brent_price  wti_price  dxy_index    vix   gpr_index  \
# 4042  06-03-26    92.690002  90.900002  98.989998  29.49  130.887665
# 4043  09-03-26    98.959999  94.769997  99.180000  25.50  130.887665
# 4044  10-03-26    87.800003  83.449997  98.830002  24.93  130.887665
# 4045  11-03-26    91.980003  87.250000  99.230003  24.23  130.887665
# 4046  12-03-26    95.760002  94.309998  99.463997  24.23  130.887665
#
#       brent_return  wti_return  brent_lag_1  brent_lag_3  ...  wti_lag_7  \
# 4042      0.085236    0.122084    85.410004    81.400002  ...  65.419998
# 4043      0.067645    0.042574    92.690002    81.400002  ...  65.209999
# 4044     -0.112773   -0.119447    98.959999    85.410004  ...  67.019997
# 4045      0.047608    0.045536    87.800003    92.690002  ...  71.230003
# 4046      0.041096    0.080917    91.980003    98.959999  ...  74.559998
#
#       brent_volatility_7d  brent_volatility_30d  wti_volatility_7d  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4047 entries, 0 to 4046
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  4047 non-null   object
#  1   brent_price           4047 non-null   float64
#  2   wti_price             4047 non-null   float64
#  3   dxy_index             4047 non-null   float64
#  4   vix                   4047 non-null   float64
#  5   gpr_index             4047 non-null   float64
#  6   brent_return          4047 non-null   float64
#  7   wti_return            4047 non-null   float64
#  8   brent_lag_1           4047 non-null   float64
#  9   brent_lag_3           4047 non-null   float64
#  10  brent_lag_7           4047 non-null   float64
#  11  wti_lag_1             4047 non-null   float64
#  12  wti_lag_3             4047 non-null   float64
#  13  wti_lag_7             4047 non-null   float64
# ...

# %%
df.describe()
# Out:
#        brent_price    wti_price    dxy_index          vix    gpr_index  \
# count  4047.000000  4047.000000  4047.000000  4047.000000  4047.000000
# mean     77.623944    71.417546    92.909040    18.393249   102.596421
# std      23.529261    20.777323     9.285512     6.853769    31.559190
# min      19.330000   -37.630001    72.930000     9.140000    58.420769
# 25%      60.785000    54.340000    82.735001    13.775000    81.389641
# 50%      75.169998    71.120003    95.309998    16.650000    93.521255
# 75%      98.155003    88.180000    99.180000    21.010000   116.716286
# max     127.980003   123.699997   114.110001    82.690002   318.954926
#
#        brent_return   wti_return  brent_lag_1  brent_lag_3  brent_lag_7  \
# count   4047.000000  4047.000000  4047.000000  4047.000000  4047.000000
# mean       0.000311    -0.000541    77.618982    77.610623    77.592315
# std        0.022377     0.058092    23.527553    23.526150    23.523086
# ...

# %%
df.dtypes
# Out:
# date                     object
# brent_price             float64
# wti_price               float64
# dxy_index               float64
# vix                     float64
# gpr_index               float64
# brent_return            float64
# wti_return              float64
# brent_lag_1             float64
# brent_lag_3             float64
# brent_lag_7             float64
# wti_lag_1               float64
# wti_lag_3               float64
# wti_lag_7               float64
# brent_volatility_7d     float64
# brent_volatility_30d    float64
# wti_volatility_7d       float64
# wti_volatility_30d      float64
# brent_wti_spread        float64
# event_type               object
# event_description        object
# event_severity            int64
# event_flag                int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# date                    0
# brent_price             0
# wti_price               0
# dxy_index               0
# vix                     0
# gpr_index               0
# brent_return            0
# wti_return              0
# brent_lag_1             0
# brent_lag_3             0
# brent_lag_7             0
# wti_lag_1               0
# wti_lag_3               0
# wti_lag_7               0
# brent_volatility_7d     0
# brent_volatility_30d    0
# wti_volatility_7d       0
# wti_volatility_30d      0
# brent_wti_spread        0
# event_type              0
# event_description       0
# event_severity          0
# event_flag              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df = df.sort_values('date')

# %%
df['rolling_volatility_30d'] = df['brent_return'].rolling(window=30).std()

# %%
df['price_direction'] = (df['brent_return'] > 0).astype(int)

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
for col in numeric_cols:
    sns.histplot(x=col, data=df, kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
for col in df:
    if df[col].dtype == 'O':
        plt.figure(figsize=(14,4))
        sns.countplot(x=col,data=df)
        plt.xticks(rotation=45)
        plt.title(f"Distribution of {col}")
        plt.show()

# %%
sns.histplot(df['brent_return'], bins=50, kde=True)
plt.title("Distribution of Daily Oil Returns")
plt.show()

# %%
sns.lineplot(x='date', y='rolling_volatility_30d', data=df)
plt.title("30-Day Rolling Oil Volatility")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='wti_price', y='brent_price', data=df)
plt.title('Wti Price vs Brent Oil Price')
plt.xlabel('Wti_Price')
plt.ylabel('Brent_Price')
sns.regplot(x='wti_price', y='brent_price', data=df)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='brent_price',y='vix',data=df)
plt.title("Brent vs VIX")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='wti_price',y='vix',data=df)
plt.title("WTI vs VIX")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='brent_price',y='dxy_index',data=df)
plt.title("Brent vs DXY Index")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='wti_price',y='dxy_index',data=df)
plt.title("WTI vs DXY Index")
plt.show()

# %%
outlier_cols = ['brent_price', 'wti_price', 'brent_return', 'wti_return', 'vix']
outlier_summary = {}

for col in outlier_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    low, high = Q1 - 1.5*IQR, Q3 + 1.5*IQR
    n_out = ((df[col] < low) | (df[col] > high)).sum()
    outlier_summary[col] = {'low': low, 'high': high, 'n': n_out}
    print(f"{col:<22} {df[col].min():>10.2f} {df[col].max():>10.2f} {low:>10.2f} {high:>10.2f} {n_out:>10}")

# Remove outliers
for col in outlier_cols:
    low = outlier_summary[col]['low']
    high = outlier_summary[col]['high']
    df = df[(df[col] >= low) & (df[col] <= high)]

print(f"\nRows before: 4047 | Rows after: {len(df)}")
# Out:
# brent_price                 19.33     127.98       4.73     154.21          0
# wti_price                  -37.63     123.70       3.58     138.94          1
# brent_return                -0.24       0.21      -0.04       0.04        237
# wti_return                  -3.06       0.38      -0.05       0.05        193
# vix                          9.14      82.69       2.92      31.86        186
#
# Rows before: 4047 | Rows after: 3640

# %%
sns.boxplot(data=df[['brent_price','wti_price','vix','dxy_index']])
plt.title("Boxplot After Outlier Removal")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='event_flag', y='brent_price', data=df)
plt.title("oil price during geopolitical events vs normal periods.")
plt.show()

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(20,14))
sns.heatmap(corr,
    annot=True,
    cmap='coolwarm',
    fmt=".2f")
plt.title("correlation HeatMap")
plt.show()

# %%
# T-test: Do oil returns differ during geopolitical events vs normal days?
event_returns = df[df['event_flag'] == 1]['brent_return']
normal_returns = df[df['event_flag'] == 0]['brent_return']

t_stat, p_value = stats.ttest_ind(event_returns, normal_returns)

print(f"Event days mean return:  {event_returns.mean():.4f}")
print(f"Normal days mean return: {normal_returns.mean():.4f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value:     {p_value:.4f}")

if p_value < 0.05:
    print("\nResult: Significant — returns ARE different during geopolitical events")
else:
    print("\nResult: Not significant — no major return difference during events")
# Out:
# Event days mean return:  0.0040
# Normal days mean return: 0.0008
# T-statistic: 0.8832
# P-value:     0.3772
#
# Result: Not significant — no major return difference during events

# %%
# Two Sample T-test: Brent vs WTI returns
t_stat, p_value = stats.ttest_ind(df['brent_return'], df['wti_return'])

print(f"Brent mean return: {df['brent_return'].mean():.4f}")
print(f"WTI mean return:   {df['wti_return'].mean():.4f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value:     {p_value:.4f}")

if p_value < 0.05:
    print("\nResult: Significant — Brent and WTI returns ARE statistically different")
else:
    print("\nResult: Not significant — Brent and WTI returns behave similarly")
# Out:
# Brent mean return: 0.0008
# WTI mean return:   0.0007
# T-statistic: 0.2128
# P-value:     0.8315
#
# Result: Not significant — Brent and WTI returns behave similarly

# %%
# Chi-square: Is there a relationship between event_type and price_direction?
contingency_table = pd.crosstab(df['event_type'], df['price_direction'])
print("Contingency Table:")
print(contingency_table)

chi2, p_value, dof, expected = stats.chi2_contingency(contingency_table)

print(f"\nChi2 statistic: {chi2:.4f}")
print(f"P-value:        {p_value:.4f}")
print(f"Degrees of freedom: {dof}")

if p_value < 0.05:
    print("\nResult: Significant — event_type IS related to price direction")
else:
    print("\nResult: Not significant — event_type has no impact on price direction")
# Out:
# Contingency Table:
# price_direction       0     1
# event_type
# annexation            1     0
# blockade              0     1
# conflict              0     4
# diplomatic_crisis     1     0
# disaster              0     1
# energy_crisis         0     1
# market_shift          1     0
# none               1740  1883
# opec                  1     0
# sanctions             2     2
# war                   1     1
#
# Chi2 statistic: 10.8056
# P-value:        0.3729
# Degrees of freedom: 10
#
# Result: Not significant — event_type has no impact on price direction

# %%
# ANOVA: Do oil prices differ across different event types?
groups = [df[df['event_type'] == etype]['brent_price'] 
          for etype in df['event_type'].unique()]

f_stat, p_value = stats.f_oneway(*groups)

print(f"F-statistic: {f_stat:.4f}")
print(f"P-value:     {p_value:.4f}")

if p_value < 0.05:
    print("\nResult: Significant — brent price differs across event types")
else:
    print("\nResult: Not significant — no major price difference across event types")
print("\nMean Brent Price by Event Type:")
print(df.groupby('event_type')['brent_price'].mean().sort_values(ascending=False).round(2))
# Out:
# F-statistic: 0.6174
# P-value:     0.8003
#
# Result: Not significant — no major price difference across event types
#
# Mean Brent Price by Event Type:
# event_type
# annexation           106.79
# war                  100.36
# disaster              84.80
# sanctions             83.25
# blockade              81.43
# energy_crisis         81.26
# none                  78.54
# conflict              74.23
# opec                  66.87
# market_shift          64.40
# diplomatic_crisis     49.47
# Name: brent_price, dtype: float64

# %%
# Class Imbalance Check
print(df['event_flag'].value_counts())
print(f"\nImbalance ratio: {df['event_flag'].value_counts()[0] / df['event_flag'].value_counts()[1]:.0f}:1")
# Out:
# event_flag
# 0    3623
# 1      17
# Name: count, dtype: int64
#
# Imbalance ratio: 213:1

# %%
# Chronological Train/Test Split (80/20)
df = df.sort_values('date').reset_index(drop=True)
split_idx = int(len(df) * 0.80)

train = df.iloc[:split_idx]
test  = df.iloc[split_idx:]

print(f"Train: {len(train)} rows | {train['date'].min().date()} → {train['date'].max().date()}")
print(f"Test:  {len(test)} rows  | {test['date'].min().date()} → {test['date'].max().date()}")
# Out:
# Train: 2912 rows | 2010-01-03 → 2023-02-16
# Test:  728 rows  | 2023-02-17 → 2026-12-02
